# %% [markdown]
# # Use mozinor for classification

# %% [markdown]
# #### Import the main module

# %%
from mozinor.baboulinet import Baboulinet
# Out:
# /home/jwuthri/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# #### Prepare the pipeline
#
#     (str) filepath: Give the csv file
#     (str) y_col: The column to predict
#     (bool) regression: Regression or Classification ?
#     (bool) process: (WARNING) apply some preprocessing on your data (tune this preprocess with params below)
#     (char) sep: delimiter
#     (list) col_to_drop: which columns you don't want to use in your prediction
#     (bool) derivate: for all features combination apply, n1 * n2, n1 / n2 ...
#     (bool) transform: for all features apply, log(n), sqrt(n), square(n)
#     (bool) scaled: scale the data ?
#     (bool) infer_datetime: for all columns check the type and build new columns from them (day, month, year, time) if they are date type
#     (str) encoding: data encoding
#     (bool) dummify: apply dummies on your categoric variables

# %%
cls = Baboulinet(filepath="toto.csv", y_col="predict", regression=False)

# %% [markdown]
# #### Now run the pipeline
#
#     May take some times

# %%
res = cls.babouline()
# Out:
# Reading the file toto.csv
# Read csv file: toto.csv
# args: {'encoding': 'utf-8-sig', 'sep': ',', 'decimal': ',', 'engine': 'python', 'filepath_or_buffer': 'toto.csv', 'thousands': '.', 'parse_dates': ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'predict'], 'infer_datetime_format': True}
# Inital dtypes is a          float64
# b          float64
# c          float64
# d          float64
# e          float64
# f          float64
# g          float64
# h          float64
# predict      int64
# dtype: object
# Work on PolynomialFeatures: degree 1
# Optimal number of clusters
# (5000, 9)
#
#     Polynomial Features: generate a new feature matrix
#     consisting of all polynomial combinations of the features.
#     For 2 features [a, b]:
#         the degree 1 polynomial give [a, b]
#         the degree 2 polynomial give [1, a, b, a^2, ab, b^2]
#     ...
#
#
#     ELBOW: explain the variance as a function of clusters.
# Optimal number of trees
#     OOB: this is the average error for each training observations,
#     calculted using the trees that doesn't contains this observation
#     during the creation of the tree.
# Estimator DecisionTreeClassifier
#     Decision Tree Classifier: poses a series of carefully crafted questions
#     about the attributes of the test record. Each time time it receive an answer,
#     a follow-up question is asked until a conclusion about the calss label
#     of the record is reached.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.7s finished
#    Best params => {'min_samples_split': 4, 'min_samples_leaf': 6, 'max_depth': 6, 'criterion': 'entropy'}
#    Best Score => 0.767
# Check the decision tree: 2017-08-1723:17:15.946105.png
# Estimator ExtraTreesClassifier
#     ExtraTreesClassifier: as in random forests, a random subset of candidate
#     features is used, but instead of looking for the most discriminative
#     thresholds, thresholds are drawn at random for each candidate feature and
#     the best of these randomly-generated thresholds is picked as
#     the splitting rule.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    5.2s finished
#    Best params => {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 0.7, 'criterion': 'gini', 'bootstrap': False}
#    Best Score => 0.805
# Estimator RandomForestClassifier
#     RandomForestClassifier: builds an ensemble of 'weeks learner' named decision
#     tree, but all taken together are a 'strong learner'.
#     The 'weeks learner' are build thanks to a split from the training set,
#     each split is the best split among a random subset of the features
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   35.1s finished
#    Best params => {'n_estimators': 100, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 0.4, 'criterion': 'entropy', 'bootstrap': True}
#    Best Score => 0.795
# Estimator GradientBoostingClassifier
#     GradientBoostingClassifier: as in random forests, a random subset of
#     candidate features is used, but the trees are builds one-by-one,
#     then the predictions of the individual trees are summed.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   23.6s finished
#    Best params => {'n_estimators': 10, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 0.6, 'max_depth': 7, 'learning_rate': 0.1}
#    Best Score => 0.793
# Estimator XGBClassifier
#     Gradient boosting is an approach where new models are created that predict
#     the residuals or errors of prior models and then added together to make
#     the final prediction. It is called gradient boosting because it uses a
#     gradient descent algorithm to minimize the loss when adding new models.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   17.0s finished
#    Best params => {'subsample': 0.4, 'n_estimators': 50, 'min_child_weight': 4, 'max_depth': 10, 'learning_rate': 0.1}
#    Best Score => 0.796
# Estimator LogisticRegression
#     LogisticRegression: explain the relationship between one dependent binary
#     variable and one or more nominal
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    6.4s finished
#    Best params => {'penalty': 'l1', 'dual': False, 'C': 0.1}
#    Best Score => 0.752
# Estimator BernoulliNB
#     BernoulliNB: for data that is distributed according to
#     multivariate Bernoulli distributions.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.2s finished
#    Best params => {'fit_prior': True, 'alpha': 1.0}
#    Best Score => 0.705
# Estimator GaussianNB
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s finished
#    Best params => {}
#    Best Score => 0.710
# Estimator KNeighborsClassifier
#     GaussianNB: the likelihood of the features is assumed to be Gaussian.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
#
#     KNeighborsClassifier: Majority vote of its k nearest neighbors.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    1.8s finished
#    Best params => {'n_neighbors': 12, 'p': 1, 'weights': 'distance'}
#    Best Score => 0.786
# Work on PolynomialFeatures: degree 2
# Optimal number of clusters
#     Polynomial Features: generate a new feature matrix
#     consisting of all polynomial combinations of the features.
#     For 2 features [a, b]:
#         the degree 1 polynomial give [a, b]
#         the degree 2 polynomial give [1, a, b, a^2, ab, b^2]
#     ...
#
#
#     ELBOW: explain the variance as a function of clusters.
# Optimal number of trees
#     OOB: this is the average error for each training observations,
#     calculted using the trees that doesn't contains this observation
#     during the creation of the tree.
# Estimator DecisionTreeClassifier
#     Decision Tree Classifier: poses a series of carefully crafted questions
#     about the attributes of the test record. Each time time it receive an answer,
#     a follow-up question is asked until a conclusion about the calss label
#     of the record is reached.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    4.9s finished
#    Best params => {'min_samples_split': 2, 'min_samples_leaf': 9, 'max_depth': 6, 'criterion': 'gini'}
#    Best Score => 0.754
# Check the decision tree: 2017-08-1723:20:27.266662.png
# Estimator ExtraTreesClassifier
#     ExtraTreesClassifier: as in random forests, a random subset of candidate
#     features is used, but instead of looking for the most discriminative
#     thresholds, thresholds are drawn at random for each candidate feature and
#     the best of these randomly-generated thresholds is picked as
#     the splitting rule.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    9.7s finished
#    Best params => {'n_estimators': 100, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.1, 'criterion': 'gini', 'bootstrap': False}
#    Best Score => 0.798
# Estimator RandomForestClassifier
#     RandomForestClassifier: builds an ensemble of 'weeks learner' named decision
#     tree, but all taken together are a 'strong learner'.
#     The 'weeks learner' are build thanks to a split from the training set,
#     each split is the best split among a random subset of the features
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  2.6min finished
#    Best params => {'n_estimators': 50, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 0.3, 'criterion': 'entropy', 'bootstrap': True}
#    Best Score => 0.795
# Estimator GradientBoostingClassifier
#     GradientBoostingClassifier: as in random forests, a random subset of
#     candidate features is used, but the trees are builds one-by-one,
#     then the predictions of the individual trees are summed.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   35.7s finished
#    Best params => {'n_estimators': 75, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 0.1, 'max_depth': 9, 'learning_rate': 0.01}
#    Best Score => 0.791
# Estimator XGBClassifier
#     Gradient boosting is an approach where new models are created that predict
#     the residuals or errors of prior models and then added together to make
#     the final prediction. It is called gradient boosting because it uses a
#     gradient descent algorithm to minimize the loss when adding new models.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   28.2s finished
#    Best params => {'subsample': 0.9, 'n_estimators': 75, 'min_child_weight': 6, 'max_depth': 2, 'learning_rate': 0.5}
#    Best Score => 0.787
# Estimator LogisticRegression
#     LogisticRegression: explain the relationship between one dependent binary
#     variable and one or more nominal
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   32.1s finished
#    Best params => {'penalty': 'l1', 'dual': False, 'C': 1.0}
#    Best Score => 0.770
# Estimator BernoulliNB
#     BernoulliNB: for data that is distributed according to
#     multivariate Bernoulli distributions.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.3s finished
#    Best params => {'fit_prior': False, 'alpha': 1.0}
#    Best Score => 0.718
# Estimator GaussianNB
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s finished
#    Best params => {}
#    Best Score => 0.566
# Estimator KNeighborsClassifier
#     GaussianNB: the likelihood of the features is assumed to be Gaussian.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
#
#     KNeighborsClassifier: Majority vote of its k nearest neighbors.
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    8.8s finished
#    Best params => {'n_neighbors': 8, 'p': 1, 'weights': 'distance'}
#    Best Score => 0.774
#                                             Estimator     Score  Degree
# 0   (ExtraTreeClassifier(class_weight=None, criter...  0.805067       1
# 1   (ExtraTreeClassifier(class_weight=None, criter...  0.798133       2
# 2   XGBClassifier(base_score=0.5, colsample_byleve...  0.796267       1
# 3   (DecisionTreeClassifier(class_weight=None, cri...  0.795467       1
# 4   (DecisionTreeClassifier(class_weight=None, cri...  0.794667       2
# 5   ([DecisionTreeRegressor(criterion='friedman_ms...  0.793067       1
# 6   ([DecisionTreeRegressor(criterion='friedman_ms...  0.791200       2
# 7   XGBClassifier(base_score=0.5, colsample_byleve...  0.787200       2
# 8   KNeighborsClassifier(algorithm='auto', leaf_si...  0.785600       1
# 9   KNeighborsClassifier(algorithm='auto', leaf_si...  0.773867       2
# 10  LogisticRegression(C=1.0, class_weight=None, d...  0.769867       2
# 11  DecisionTreeClassifier(class_weight=None, crit...  0.767467       1
# 12  DecisionTreeClassifier(class_weight=None, crit...  0.754400       2
# 13  LogisticRegression(C=0.1, class_weight=None, d...  0.752000       1
# 14  BernoulliNB(alpha=1.0, binarize=0.0, class_pri...  0.717600       2
# 15                            GaussianNB(priors=None)  0.710400       1
# 16  BernoulliNB(alpha=1.0, binarize=0.0, class_pri...  0.704533       1
# 17                            GaussianNB(priors=None)  0.565600       2
#     Stacking: is a model ensembling technique used to combine information
#     from multiple predictive models to generate a new model.
#
# task:   [classification]
# metric: [accuracy_score]
#
# model 0: [ExtraTreesClassifier]
#     ----
#     MEAN:   [0.80773333]
#
# model 1: [XGBClassifier]
#     ----
#     MEAN:   [0.79306667]
#
# model 2: [RandomForestClassifier]
#     ----
#     MEAN:   [0.79520000]
#
# model 3: [GradientBoostingClassifier]
#     ----
#     MEAN:   [0.79173333]
#
# model 4: [KNeighborsClassifier]
#     ----
#     MEAN:   [0.78240000]
#
# model 5: [DecisionTreeClassifier]
#     ----
#     MEAN:   [0.76320000]
#
# model 6: [LogisticRegression]
#   0%|          | 0/511 [00:00<?, ?it/s]
#     ----
#     MEAN:   [0.75093333]
#
# model 7: [GaussianNB]
#     ----
#     MEAN:   [0.70933333]
#
# model 8: [BernoulliNB]
#     ----
#     MEAN:   [0.71093333]
# Stacking 9 models: 100%|██████████| 511/511 [09:43<00:00,  1.87s/it]

# %% [markdown]
# ## The class instance, now contains 2 objects, the model for this data, and the best stacking for this data

# %% [markdown]
# ### To make auto generate the code of the model

# %% [markdown]
# #### Generate the code for the best model

# %%
cls.bestModelScript()
# Out:
# Check script file toto_solo_model_script.py
# 'toto_solo_model_script.py'

# %% [markdown]
# #### Generate the code for the best stacking

# %%
cls.bestStackModelScript()
# Out:
# Check script file toto_stack_model_script.py
# 'toto_stack_model_script.py'

# %% [markdown]
# ### To check which model is the best

# %% [markdown]
# #### Best model

# %%
res.best_model
# Out:
# Estimator    (ExtraTreeClassifier(class_weight=None, criter...
# Score                                                 0.805067
# Degree                                                       1
# Name: 0, dtype: object

# %%
show = """
    Model: {},
    Score: {}
"""
print(show.format(res.best_model["Estimator"], res.best_model["Score"]))
# Out:
#     Model: ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features=0.7, max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=10, min_weight_fraction_leaf=0.0,
#            n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False),
#     Score: 0.8050666666666667

# %% [markdown]
# #### Best stacking

# %%
res.best_stack_models
# Out:
# Fit1stLevelEstimator    [(ExtraTreeClassifier(class_weight=None, crite...
# Fit2ndLevelEstimator    BernoulliNB(alpha=1.0, binarize=0.0, class_pri...
# Score                                                              0.4936
# Degree                                                                  1
# Name: 0, dtype: object

# %%
show = """
    FirstModel: {},
    SecondModel: {},
    Score: {}
"""
print(show.format(res.best_stack_models["Fit1stLevelEstimator"], res.best_stack_models["Fit2ndLevelEstimator"], res.best_stack_models["Score"]))
# Out:
#     FirstModel: [ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features=0.7, max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=10, min_weight_fraction_leaf=0.0,
#            n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False), XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=10,
#        min_child_weight=4, missing=None, n_estimators=50, nthread=-1,
#        objective='multi:softprob', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=0.4), RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features=0.4, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=3,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False), DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=6,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=6,
#             min_samples_split=4, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'), GaussianNB(priors=None), BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)],
#     SecondModel: BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True),
#     Score: 0.4936

# %%
res
